# %% [markdown]
# <a href="https://colab.research.google.com/github/KacperWodiczko/ZabkaProject-/blob/main/Projekt_%C5%BBabka_Kacper_Wodiczko.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Biblioteki

# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

# %matplotlib inline

import seaborn as sns

from bs4 import BeautifulSoup

import requests

from geopy.geocoders import Nominatim

import folium

# !pip install geocoder

import geocoder

import unicodedata
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 3.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# HTML strony na Wikipedii

# %%
wiki_url = "https://pl.wikipedia.org/wiki/Dzielnice_Gdyni"

# If the request was successful, reponse should be '200'.
response = requests.get(wiki_url)

print(response. text)

# %% [markdown]
# Scrapowanie Wikipedii

# %%
# URL strony na Wikipedii z danymi o dzielnicach.
wiki_url = "https://pl.wikipedia.org/wiki/Dzielnice_Gdyni"

# If the request was successful, reponse should be '200'.
page = requests.get(wiki_url)

# Parse response content to html with BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# Find the right table in the HTML sourcecode

results = soup.find("table", class_= "wikitable sortable")


# Placeholder for list of neighbourhoods
gdynia_dzielnice = []
rows = results.find_all("tr")
for row in rows:
  cells = row.find_all(["th", "td"])
  row_data = [cell.text.strip() for cell in cells]
  if row_data:
    gdynia_dzielnice.append(row_data)


df_gdynia = pd.DataFrame(gdynia_dzielnice, columns=["Numer", "Nazwa dzielnicy", "Liczba ludności", "Powierzchnia[km²", "Gęstość zaludnienia[osób/km²]"]).dropna()
df_gdynia["Nazwa dzielnicy"].tolist()
# Out:
# ['Nazwa dzielnicy',
#  'Babie Doły',
#  'Chwarzno-Wiczlino',
#  'Chylonia',
#  'Cisowa',
#  'Działki Leśne',
#  'Dąbrowa',
#  'Grabówek',
#  'Kamienna Góra',
#  'Karwiny',
#  'Leszczynki',
#  'Mały Kack',
#  'Obłuże',
#  'Oksywie',
#  'Orłowo',
#  'Pogórze',
#  'Pustki Cisowskie-Demptowo',
#  'Redłowo',
#  'Śródmieście',
#  'Wielki Kack',
#  'Witomino',
#  'Wzgórze św. Maksymiliana',
#  'Razem:']

# %%
url = "https://gdynia.w-poblizu.pl/zabka/"

page = requests.get(url)

soup = BeautifulSoup(page.content, 'html.parser')

results = soup.find("div", class_= "list").find_all("a", class_="opened")

df_zabka = pd.DataFrame(results, columns=["ŻABKI"])
df_zabka["ŻABKI"]
# Out:
# 0             Żabka ID05822, 10 Lutego 32 lok. 4, Gdynia
# 1                     Żabka ID04013, 10 Lutego 9, Gdynia
# 2                       Żabka ID01618, 3 Maja 20, Gdynia
# 3      Żabka ID08841, al. Piłsudskiego 32A lok.U1, Gd...
# 4               Żabka ID04762, Arenda Dickmana 4, Gdynia
#                              ...
# 126           Żabka ID08599, WŁADYSŁAWA IV 46/U4, Gdynia
# 127            Żabka ID03757, Wójta Radtkego 47A, Gdynia
# 128              Żabka ID06044, Zaruskiego 10/U1, Gdynia
# 129                    Żabka ID08758, Zielona 23, Gdynia
# 130         Żabka ID04998, Zwycięstwa 239 lok. 2, Gdynia
# Name: ŻABKI, Length: 131, dtype: object

# %%
dzielnice = ['Babie Doly',
 'Chwarzno-Wiczlino',
 'Chylonia',
 'Cisowa',
 'Dzialki Lesne',
 'Dabrowa',
 'Grabowek',
 'Kamienna Gora',
 'Karwiny',
 'Leszczynki',
 'Maly Kack',
 'Obluze',
 'Oksywie',
 'Orlowo',
 'Pogorze',
 'Pustki Cisowskie-Demptowo',
 'Redlowo',
 'Srodmiescie',
 'Wielki Kack',
 'Witomino',
 'Wzgórze sw. Maksymiliana',]

# %%
geolocator = Nominatim(user_agent="http")

address_coordinates_dict = {}
for dzielnica in dzielnice:
    location = geolocator.geocode(dzielnica)
    address_coordinates_dict[dzielnica] = (location.latitude, location.longitude)
    print(location.latitude, location.longitude)
# Out:
# 48.8220826 18.098727
# 54.5020496 18.419272789753748
# 54.3227085 10.135555
# 51.4423143 19.5654021
# 54.514046699999994 18.520312681018645
# 49.8588022 18.4801908
# 53.8561337 21.6966278
# 50.78468925 16.022363067768467
# 54.4720926 18.4962984
# 54.2904413 17.9370058
# 54.4866885 18.5235025
# 54.5531148 18.5175055
# 54.55184 18.5443851
# 49.8459427 18.4309274
# 49.8000292 18.8379682
# 54.53447 18.4529088
# 54.4923852 18.55131783315398
# 52.2328098 21.019067
# 54.4676639 18.4928425
# 54.4984985 18.509001
# 54.5035859 18.541057

# %%
latitude = [54.5813827,
54.5020496,
54.3227085,
51.4423143,
54.514046699999994,
52.9663293,
53.8561337,
50.78468925,
54.4720926,
54.2904413,
54.4866885,
54.5531148,
54.55184,
49.8459427,
49.8000292,
54.53447,
54.4923852,
52.2328098,
54.4676639,
54.4984985,
54.5029646]

# %%
longitude = [18.5394172,
18.419272789753748,
10.135555,
19.5654021,
18.520312681018645,
20.2781539,
21.6966278,
16.022363067768467,
18.4962984,
17.9370058,
18.5235025,
18.5175055,
18.5443851,
18.4309274,
18.8379682,
18.4529088,
18.55131783315398,
21.019067,
18.4928425,
18.509001,
18.543279699264005]

# %%
geolocator = Nominatim(user_agent="http")

# %%
address_coordinates_dict = {}
for dzielnica in dzielnice:
    location = geolocator.geocode(dzielnica)
    address_coordinates_dict[dzielnica] = (location.latitude, location.longitude)
    print(location.longitude)
# Out:
# 18.098727
# 18.419272789753748
# 10.135555
# 19.5654021
# 18.520312681018645
# 18.4801908
# 21.6966278
# 16.022363067768467
# 18.4962984
# 17.9370058
# 18.5235025
# 18.5175055
# 18.5443851
# 18.4309274
# 18.8379682
# 18.4529088
# 18.55131783315398
# 21.019067
# 18.4928425
# 18.509001
# 18.541057

# %%
coordinates = [54.5813827, 18.5394172,
54.5020496, 18.419272789753748,
54.3227085, 10.135555,
51.4423143, 19.5654021,
54.514046699999994, 18.520312681018645,
52.9663293, 20.2781539,
53.8561337, 21.6966278,
50.78468925, 16.022363067768467,
54.4720926, 18.4962984,
54.2904413, 17.9370058,
54.4866885, 18.5235025,
54.5531148, 18.5175055,
54.55184, 18.5443851,
49.8459427, 18.4309274,
49.8000292, 18.8379682,
54.53447, 18.4529088,
54.4923852, 18.55131783315398,
52.2328098, 21.019067,
54.4676639, 18.4928425,
54.4984985, 18.509001,
54.5029646, 18.543279699264005,]

# %%
df_coordinates = pd.DataFrame({"Latitude":latitude, "Longitude":longitude})

df_coordinates["Dzielnice"] = pd.DataFrame(dzielnice)

df_coordinates
# Out:
#      Latitude  Longitude                  Dzielnice
# 0   54.581383  18.539417                 Babie Doly
# 1   54.502050  18.419273          Chwarzno-Wiczlino
# 2   54.322708  10.135555                   Chylonia
# 3   51.442314  19.565402                     Cisowa
# 4   54.514047  18.520313              Dzialki Lesne
# 5   52.966329  20.278154                    Dabrowa
# 6   53.856134  21.696628                   Grabowek
# 7   50.784689  16.022363              Kamienna Gora
# 8   54.472093  18.496298                    Karwiny
# 9   54.290441  17.937006                 Leszczynki
# 10  54.486688  18.523502                  Maly Kack
# 11  54.553115  18.517505                     Obluze
# 12  54.551840  18.544385                    Oksywie
# 13  49.845943  18.430927                     Orlowo
# 14  49.800029  18.837968                    Pogorze
# 15  54.534470  18.452909  Pustki Cisowskie-Demptowo
# 16  54.492385  18.551318                    Redlowo
# ...

# %%
df_coordinates
# Out:
#      Latitude  Longitude                  Dzielnice
# 0   54.581383  18.539417                 Babie Doly
# 1   54.502050  18.419273          Chwarzno-Wiczlino
# 2   54.322708  10.135555                   Chylonia
# 3   51.442314  19.565402                     Cisowa
# 4   54.514047  18.520313              Dzialki Lesne
# 5   52.966329  20.278154                    Dabrowa
# 6   53.856134  21.696628                   Grabowek
# 7   50.784689  16.022363              Kamienna Gora
# 8   54.472093  18.496298                    Karwiny
# 9   54.290441  17.937006                 Leszczynki
# 10  54.486688  18.523502                  Maly Kack
# 11  54.553115  18.517505                     Obluze
# 12  54.551840  18.544385                    Oksywie
# 13  49.845943  18.430927                     Orlowo
# 14  49.800029  18.837968                    Pogorze
# 15  54.534470  18.452909  Pustki Cisowskie-Demptowo
# 16  54.492385  18.551318                    Redlowo
# ...

# %%
def get_coordinates(row):

    lat_lng_coords = None


    while(lat_lng_coords is None):
      g = geocoder.arcgis(f'{row["Dzielnice"]}, Gdynia')
      lat_lng_coords = g.latlng

    return pd.Series([lat_lng_coords[0], lat_lng_coords[1]])


df_coordinates[['Latitude','Longitude']] = df_coordinates.apply(get_coordinates, axis=1)
df_coordinates
# Out:
#      Latitude  Longitude                  Dzielnice
# 0   54.581090  18.539655                 Babie Doly
# 1   54.502146  18.466309          Chwarzno-Wiczlino
# 2   54.544120  18.469076                   Chylonia
# 3   54.549197  18.444791                     Cisowa
# 4   54.514737  18.532677              Dzialki Lesne
# 5   54.471925  18.462430                    Dabrowa
# 6   54.526834  18.511630                   Grabowek
# 7   54.511642  18.546799              Kamienna Gora
# 8   54.473447  18.490217                    Karwiny
# 9   54.533020  18.488830                 Leszczynki
# 10  54.477864  18.522656                  Maly Kack
# 11  54.552381  18.515204                     Obluze
# 12  54.549540  18.539610                    Oksywie
# 13  54.479333  18.552430                     Orlowo
# 14  54.558545  18.475330                    Pogorze
# 15  54.533642  18.452914  Pustki Cisowskie-Demptowo
# 16  54.492582  18.546783                    Redlowo
# ...

# %%
df_coordinates['Latitude']
# Out:
# 0     54.581090
# 1     54.502146
# 2     54.544120
# 3     54.549197
# 4     54.514737
# 5     54.471925
# 6     54.526834
# 7     54.511642
# 8     54.473447
# 9     54.533020
# 10    54.477864
# 11    54.552381
# 12    54.549540
# 13    54.479333
# 14    54.558545
# 15    54.533642
# 16    54.492582
# 17    54.519340
# 18    54.467997
# 19    54.498092
# 20    54.503087
# Name: Latitude, dtype: float64

# %%
address = 'Gdynia, Polska'
geolocator = Nominatim(user_agent="Kacpero")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(f'The geograpical coordinates of Gdynia are {latitude}, {longitude}')
# Out:
# The geograpical coordinates of Gdynia are 54.5164982, 18.5402738

# %%
def remove_accents(input_str):
    nfkd_form = unicodedata.normalize('NFKD', input_str)
    only_ascii = nfkd_form.encode('ASCII', 'ignore')
    return only_ascii.decode("utf-8")

# %%
map_gdynia = folium.Map(location=[latitude, longitude], zoom_start=11)


for lat, lng, label in zip(df_coordinates['Latitude'], df_coordinates['Longitude'], df_coordinates["Dzielnice"]):
    label = folium.Popup(remove_accents(label), parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_gdynia)

map_gdynia
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
df_gdynia
# Out:
#    Numer            Nazwa dzielnicy  Liczba ludności   Powierzchnia[km²  \
# 0     Nr            Nazwa dzielnicy  Liczba ludności  Powierzchnia[km²]
# 1      1                 Babie Doły             1944               2,21
# 2      2          Chwarzno-Wiczlino           13 450              25,53
# 3      3                   Chylonia           20 717               3,84
# 4      4                     Cisowa           11 016               5,78
# 5      5              Działki Leśne             7382               1,95
# 6      6                    Dąbrowa           13 636               6,23
# 7      7                   Grabówek             8153               4,38
# 8      8              Kamienna Góra             3866               0,65
# 9      9                    Karwiny             9731               3,39
# 10    10                 Leszczynki             7127               2,75
# 11    11                  Mały Kack             9645               7,94
# ...

# %%
 df_zabka
# Out:
#                                                  ŻABKI
# 0           Żabka ID05822, 10 Lutego 32 lok. 4, Gdynia
# 1                   Żabka ID04013, 10 Lutego 9, Gdynia
# 2                     Żabka ID01618, 3 Maja 20, Gdynia
# 3    Żabka ID08841, al. Piłsudskiego 32A lok.U1, Gd...
# 4             Żabka ID04762, Arenda Dickmana 4, Gdynia
# ..                                                 ...
# 126         Żabka ID08599, WŁADYSŁAWA IV 46/U4, Gdynia
# 127          Żabka ID03757, Wójta Radtkego 47A, Gdynia
# 128            Żabka ID06044, Zaruskiego 10/U1, Gdynia
# 129                  Żabka ID08758, Zielona 23, Gdynia
# 130       Żabka ID04998, Zwycięstwa 239 lok. 2, Gdynia
#
# [131 rows x 1 columns]

# %%
df_zabka["ŻABKI"].tolist()

# %%
zaba = ['Żabka ID05822, 10 Lutego 32 lok. 4, Gdynia',
 'Żabka ID04013, 10 Lutego 9, Gdynia',
 'Żabka ID01618, 3 Maja 20, Gdynia',
 'Żabka ID08841, al. Piłsudskiego 32A lok.U1, Gdynia',
 'Żabka ID04762, Arenda Dickmana 4, Gdynia',
 'Żabka ID08231, Beniowskiego 29, Gdynia',
 'Żabka ID04055, Benisławskiego 1, Gdynia',
 'Żabka ID08427, Benisławskiego 48, Gdynia',
 'Żabka ID01440, Boh. Starówki Warszawskiej 3, Gdynia',
 'Żabka ID04094, Boisko 11, Gdynia',
 'Żabka ID04061, Bosmańska 38, Gdynia',
 'Żabka ID01003, Buraczana 25, Gdynia',
 'Żabka ID05471, Cechowa 8, Gdynia',
 'Żabka ID00939, Chylońska 251B, Gdynia',
 'Żabka ID05094, Chylońska 26, Gdynia',
 'Żabka ID05403, Chylońska 44 lok. 1, Gdynia',
 'Żabka ID00976, Chylońska 91A, Gdynia',
 'Żabka ID05466, Dragonów 1A, Gdynia',
 'Żabka ID07108, Hieronima Derdowskiego 5, Gdynia',
 'Żabka ID04780, Horyda 8, Gdynia',
 'Żabka ID03974, Kartuska 41a, Gdynia',
 'Żabka ID03163, Kartuska 6, Gdynia',
 'Żabka ID00950, Kornela Ujejskiego 29-35 lok. UI/17, Gdynia',
 'Żabka ID03582, Legionów 112/7, Gdynia',
 'Żabka ID04350, Legionów 115A/L1, Gdynia',
 'Żabka ID01453, Morska 115, Gdynia',
 'Żabka ID04465, Morska 176- 184 A-D lok. 115, Gdynia',
 'Żabka ID04757, Morska 217, Gdynia',
 'Żabka ID01460, Mściwoja 2/U1, Gdynia',
 'Żabka ID04351, Mylna 1/5, Gdynia',
 'Żabka ID04643, Myśliwska 27 lok. 1U, Gdynia',
 'Żabka ID05197, Nowodworcowa 20, Gdynia',
 'Żabka ID08774, Paprykowa 12A, Gdynia',
 'Żabka ID01385, Plac Kaszubski 5, Gdynia',
 'Żabka ID01733, Pl. Górnośląski 1, Gdynia',
 'Żabka ID08550, Rdestowa 10/3A, Gdynia',
 'Żabka ID05768, Skwer Kościuszki 17-19, Gdynia',
 'Żabka ID04940, Śląska 51 BL. I KL. I LOK. 141, Gdynia',
 'Żabka ID04674, Słoneczna 2 lok. 2, Gdynia',
 'Żabka ID04578, Sokola 9, Gdynia',
 'Żabka ID03584, Staniszewskiego 15/U6, Gdynia',
 'Żabka ID08525, Świętojańska 103/U1, Gdynia',
 'Żabka ID08533, Świętojańska 46/02, Gdynia',
 'Żabka ID0B534, UL. 10 LUTEGO 11 LOK. K1/C/05 ., Gdynia',
 'Żabka ID06246, ul. Abrahama 62, Gdynia',
 'Żabka ID0C555, UL. ADMIRAŁA JÓZEFA UNRUGA 118, Gdynia',
 'Żabka ID08234, ul. Amona 10, Gdynia',
 'Żabka ID08036, ul. Armii Krajowej 30, Gdynia',
 'Żabka ID05849, ul. Ateny 17, Gdynia',
 'Żabka ID0A406, UL. BIESZCZADZKA 6 LOK. 28, Gdynia',
 'Żabka ID0B133, UL. BOSMAŃSKA 3 lok. 103 i 104 ., Gdynia',
 'Żabka ID07640, ul. Bydgoska 5 lok. 5, Gdynia',
 'Żabka ID02145, ul. Chabrowa 57, Gdynia',
 'Żabka ID08220, ul. Chwaszczyńska 21, Gdynia',
 'Żabka ID0C127, UL. CHYLOŃSKA 106 ., Gdynia',
 'Żabka ID09610, ul. Chylońska 164 lok U1, Gdynia',
 'Żabka ID09709, ul. Chylońska 240, Gdynia',
 'Żabka ID07473, ul. Felińskiego 1 lok. U-4 i U-5, Gdynia',
 'Żabka ID03308, ul. Filipkowskiego 2/U1, Gdynia',
 'Żabka ID01525, ul. Gniewska 13, Gdynia',
 'Żabka ID06654, ul. Gniewska 24A lok. 2, Gdynia',
 'Żabka ID08235, ul. Hodowlana 36, Gdynia',
 'Żabka ID02276, ul. II Morskiego Pułku Strzelców 4a, Gdynia',
 'Żabka ID08998, ul. Janki Bryla 35 lok U1, Gdynia',
 'Żabka ID03444, ul. Kapitańska 20, Gdynia',
 'Żabka ID09229, ul. Kartuska 15 lok. 2, Gdynia',
 'Żabka ID0A612, UL. KAZIMIERZA GÓRSKIEGO 1 lok. 13, Gdynia',
 'Żabka ID06724, ul. Komandorska 57, Gdynia',
 'Żabka ID08236, ul. Konwaliowa 16, Gdynia',
 'Żabka ID09116, ul. Kopernika 15A lok 12 i I, Gdynia',
 'Żabka ID06322, ul. Krasickiego 10, Gdynia',
 'Żabka ID06465, ul. Krasickiego 45, Gdynia',
 'Żabka ID0B655, UL. KRAUZEGO 10 B LOK. 32 I 33, Gdynia',
 'Żabka ID06652, ul. Ledóchowskiego 6 lok. 1, Gdynia',
 'Żabka ID0A091, UL. LEGIONÓW 116 LOK. A40 ., Gdynia',
 'Żabka ID03443, ul. Legionów 92, Gdynia',
 'Żabka ID06717, ul. Łużycka 8A lok. 0.A, Gdynia',
 'Żabka ID02619, ul. Marii Wittekówny 2/8, Gdynia',
 'Żabka ID0B021, UL. MIĘTOWA 3 LOK. 08 ., Gdynia',
 'Żabka ID0C412, UL. MORSKA 139A LOK. 1 I 2, Gdynia',
 'Żabka ID09874, UL. MORSKA 15 lok. 8, Gdynia',
 'Żabka ID00587, UL. Morska 175, Gdynia',
 'Żabka ID09696, ul. MORSKA 271, Gdynia',
 'Żabka ID0C249, UL. MORSKA 53-55 ., Gdynia',
 'Żabka ID02064, ul. Morska 95/2, Gdynia',
 'Żabka ID0B515, UL. NARCYZOWA 1, Gdynia',
 'Żabka ID02116, ul. Nauczycielska 6, Gdynia',
 'Żabka ID06988, ul. Nowowiczlińska dz. nr3325, Gdynia',
 'Żabka ID0B667, UL. OLGIERDA 71A, Gdynia',
 'Żabka ID03091, ul. Opata Hackiego 17/U1, Gdynia',
 'Żabka ID03124, ul. Parkowa 6/1A, Gdynia',
 'Żabka ID08232, ul. Powstania Wielkopol. 95, Gdynia',
 'Żabka ID09280, ul. Rdestowa 138A lok.32 i 33, Gdynia',
 'Żabka ID0B994, UL. ROZEWSKA 18, Gdynia',
 'Żabka ID09389, ul. Rybickiego 2 lok. U1, Gdynia',
 'Żabka ID02438, ul. Sikorskiego 2A, Gdynia',
 'Żabka ID00504, ul. Śląska 31, Gdynia',
 'Żabka ID0C220, UL. ŚMIDOWICZA 67 LOK. 1 ., Gdynia',
 'Żabka ID0A709, UL. SOKOŁA 15, Gdynia',
 'Żabka ID08046, ul. Starowiejska 11, Gdynia',
 'Żabka ID03076, ul. Starowiejska 42-48/I, Gdynia',
 'Żabka ID06849, ul. Stefana Batorego 9 lok. U1, Gdynia',
 'Żabka ID03123, ul. Swarzewska 50A, Gdynia',
 'Żabka ID07599, ul. Świętojańska 120, Gdynia',
 'Żabka ID02870, ul. Świętojańska 4-8, Gdynia',
 'Żabka ID06604, ul. Świętojańska 57 LOK. B, Gdynia',
 'Żabka ID02993, ul. Świętojańska 79 lok.a, Gdynia',
 'Żabka ID07442, ul. Świętojańska 96 Lok. L1, Gdynia',
 'Żabka ID0C221, UL. SZCZECIŃSKA 1, Gdynia',
 'Żabka ID0A753, UL. TYMIANKOWA 18, Gdynia',
 'Żabka ID03445, ul. Warszawska 66, Gdynia',
 'Żabka ID09190, ul. Węglowa 22 LOK. U.0.4 i U.0.5, Gdynia',
 'Żabka ID06542, ul. Widna 7A, Gdynia',
 'Żabka ID02191, ul. Wincentego Pola 15, Gdynia',
 'Żabka ID0C252, UL. WŁADYSŁAWA IV 21 ., Gdynia',
 'Żabka ID02803, ul. Władysława IV 53/1, Gdynia',
 'Żabka ID0C360, UL. WŁADYSŁAWA WAGNERA 16 LOK. 24 ., Gdynia',
 'Żabka ID02902, ul. Wolności 1/2 i B, Gdynia',
 'Żabka ID0C275, UL. ŻELAZNA 9 ., Gdynia',
 'Żabka ID09625, ul. Żeromskiego 23 lok. 1004, Gdynia',
 'Żabka ID0A796, UL. ŹRÓDŁO MARII 4, Gdynia',
 'Żabka ID05773, Unruga 48A lok. 2, Gdynia',
 'Żabka ID08474, Wiejska 1, Gdynia',
 'Żabka ID04242, Wielkokacka 17, Gdynia',
 'Żabka ID09555, Władysława Grabowskiego 7 lok. 20, Gdynia',
 'Żabka ID03613, Władysława IV 32-36 Uż.3 kl.32, Gdynia',
 'Żabka ID08599, WŁADYSŁAWA IV 46/U4, Gdynia',
 'Żabka ID03757, Wójta Radtkego 47A, Gdynia',
 'Żabka ID06044, Zaruskiego 10/U1, Gdynia',
 'Żabka ID08758, Zielona 23, Gdynia',
 'Żabka ID04998, Zwycięstwa 239 lok. 2, Gdynia']

# %%
def geocode_address(address):
    geolocator = Nominatim(user_agent="myGeocoder")
    location = geolocator.geocode(address)
    if location:
        return location.latitude, location.longitude
    else:
        return None, None

# %%
geolocator = Nominatim(user_agent="http", timeout=200)

# %%
zabki = ['ul. 10 Lutego 32 lok. 4, Gdynia',
      '10 Lutego 9, Gdynia',
      '3 Maja 20, Gdynia',
      'al. Piłsudskiego 32A lok.U1, Gdynia',
      'Arenda Dickmana 4, Gdynia',
 'Beniowskiego 29, Gdynia',
 'Benisławskiego 1, Gdynia',
 'Benisławskiego 48, Gdynia',
  'Boh. Starówki Warszawskiej 3, Gdynia',
  'Boisko 11, Gdynia',
  'Bosmańska 38, Gdynia',
  'Buraczana 25, Gdynia',
 'Cechowa 8, Gdynia',
 'Chylońska 251B, Gdynia',
 'Chylońska 26, Gdynia',
  'Chylońska 44 lok. 1, Gdynia',
 'Chylońska 91A, Gdynia',
 'Dragonów 1A, Gdynia',
 'Hieronima Derdowskiego 5, Gdynia',
 'Horyda 8, Gdynia',
 'Kartuska 41a, Gdynia',
  'Kartuska 6, Gdynia',
 'Kornela Ujejskiego 29-35 lok. UI/17, Gdynia',
 'Legionów 112/7, Gdynia',
 'Legionów 115A/L1, Gdynia',
  'Morska 115, Gdynia',
 'Morska 176- 184 A-D lok. 115, Gdynia',
 'Morska 217, Gdynia',
 'Mściwoja 2/U1, Gdynia',
  'Mylna 1/5, Gdynia',
 'Myśliwska 27 lok. 1U, Gdynia',
'Nowodworcowa 20, Gdynia',
 'Paprykowa 12A, Gdynia',
'Plac Kaszubski 5, Gdynia',
  'Pl. Górnośląski 1, Gdynia',
 'Rdestowa 10/3A, Gdynia',
 'Skwer Kościuszki 17-19, Gdynia',
 'Śląska 51 BL. I KL. I LOK. 141, Gdynia',
 'Słoneczna 2 lok. 2, Gdynia',
 'Sokola 9, Gdynia',
 'Staniszewskiego 15/U6, Gdynia',
 'Świętojańska 103/U1, Gdynia',
'Świętojańska 46/02, Gdynia',
 'UL. 10 LUTEGO 11 LOK. K1/C/05 ., Gdynia',
 'ul. Abrahama 62, Gdynia',
  'UL. ADMIRAŁA JÓZEFA UNRUGA 118, Gdynia',
 'ul. Amona 10, Gdynia',
 'ul. Armii Krajowej 30, Gdynia',
 'ul. Ateny 17, Gdynia',
 'UL. BIESZCZADZKA 6 LOK. 28, Gdynia',
 'UL. BOSMAŃSKA 3 lok. 103 i 104 ., Gdynia',
 'ul. Bydgoska 5 lok. 5, Gdynia',
'ul. Chabrowa 57, Gdynia',
 'ul. Chwaszczyńska 21, Gdynia',
'UL. CHYLOŃSKA 106 ., Gdynia',
 'ul. Chylońska 164 lok U1, Gdynia',
 'ul. Chylońska 240, Gdynia',
 'ul. Felińskiego 1 lok. U-4 i U-5, Gdynia',
'ul. Filipkowskiego 2/U1, Gdynia',
'ul. Gniewska 13, Gdynia',
 'ul. Gniewska 24A lok. 2, Gdynia',
 'ul. Hodowlana 36, Gdynia',
 'ul. II Morskiego Pułku Strzelców 4a, Gdynia',
 'ul. Janki Bryla 35 lok U1, Gdynia',
 'ul. Kapitańska 20, Gdynia',
 'ul. Kartuska 15 lok. 2, Gdynia',
 'UL. KAZIMIERZA GÓRSKIEGO 1 lok. 13, Gdynia',
'ul. Komandorska 57, Gdynia',
 'Konwaliowa 16, Gdynia',
'Kopernika 15A lok 12 i I, Gdynia',
'Krasickiego 10, Gdynia',
'Krasickiego 45, Gdynia',
'KRAUZEGO 10 B LOK. 32 I 33, Gdynia',
 'Ledóchowskiego 6 lok. 1, Gdynia',
 'LEGIONÓW 116 LOK. A40 ., Gdynia',
 'Legionów 92, Gdynia',
 'Łużycka 8A lok. 0.A, Gdynia',
 'Marii Wittekówny 2/8, Gdynia',
 'MIĘTOWA 3 LOK. 08 ., Gdynia',
 'MORSKA 139A LOK. 1 I 2, Gdynia',
 'MORSKA 15 lok. 8, Gdynia',
'Morska 175, Gdynia',
 'MORSKA 271, Gdynia',
'MORSKA 53-55 ., Gdynia',
 'Morska 95/2, Gdynia',
'NARCYZOWA 1, Gdynia',
'Nauczycielska 6, Gdynia',
'Nowowiczlińska dz. nr3325, Gdynia',
'OLGIERDA 71A, Gdynia',
 'Opata Hackiego 17/U1, Gdynia',
 'Parkowa 6/1A, Gdynia',
 'Powstania Wielkopol. 95, Gdynia',
 'Rdestowa 138A lok.32 i 33, Gdynia',
 'ROZEWSKA 18, Gdynia',
'Rybickiego 2 lok. U1, Gdynia',
'Sikorskiego 2A, Gdynia',
'Śląska 31, Gdynia',
'ŚMIDOWICZA 67 LOK. 1 ., Gdynia',
'SOKOŁA 15, Gdynia',
 'Starowiejska 11, Gdynia',
'Starowiejska 42-48/I, Gdynia',
'Stefana Batorego 9 lok. U1, Gdynia',
'Swarzewska 50A, Gdynia',
'Świętojańska 120, Gdynia',
'Świętojańska 4-8, Gdynia',
'Świętojańska 57 LOK. B, Gdynia',
'Świętojańska 79 lok.a, Gdynia',
'Świętojańska 96 Lok. L1, Gdynia',
'SZCZECIŃSKA 1, Gdynia',
'TYMIANKOWA 18, Gdynia',
'Warszawska 66, Gdynia',
'Węglowa 22 LOK. U.0.4 i U.0.5, Gdynia',
 'Widna 7A, Gdynia',
 'Wincentego Pola 15, Gdynia',
'WŁADYSŁAWA IV 21 ., Gdynia',
 'Władysława IV 53/1, Gdynia',
 'WŁADYSŁAWA WAGNERA 16 LOK. 24 ., Gdynia',
 'Wolności 1/2 i B, Gdynia',
 'ŻELAZNA 9 ., Gdynia',
'Żeromskiego 23 lok. 1004, Gdynia',
 'ŹRÓDŁO MARII 4, Gdynia',
 'Unruga 48A lok. 2, Gdynia',
 'Wiejska 1, Gdynia',
 'Wielkokacka 17, Gdynia',
'Władysława Grabowskiego 7 lok. 20, Gdynia',
 'Władysława IV 32-36 Uż.3 kl.32, Gdynia',
 'WŁADYSŁAWA IV 46/U4, Gdynia',
'Wójta Radtkego 47A, Gdynia',
 'Zaruskiego 10/U1, Gdynia',
'Zielona 23, Gdynia',
 'Zwycięstwa 239 lok. 2, Gdynia']

# %%
address_coordinates_dict = {}
for address in zabki:
    location = geolocator.geocode(address)
    if location:
      address_coordinates_dict[address] = (location.latitude, location.longitude)
      print(location.latitude, location.longitude)

    else:
      pass

zabki_wspolrzedne =location.latitude, location.longitude

# %%
zabki_wspolrzedne = (location.latitude, location.longitude)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-95a26f0892fa> in <cell line: 1>()
# ----> 1 zabki_wspolrzedne = (location.latitude, location.longitude)
#
# AttributeError: 'NoneType' object has no attribute 'latitude'

# %%
address_coordinates_dict

# %%
zabki_wspolrzedne['Latitude','Latitude']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Latitude', 'Latitude')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
zabi_skok = df[['Latitude', 'Longitude']] = df.apply(geocode_address).apply(pd.Series)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-c3d3c970b6da> in <cell line: 1>()
# ----> 1 zabi_skok = df[['Latitude', 'Longitude']] = df.apply(geocode_address).apply(pd.Series)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3966             self._setitem_frame(key, value)
#    3967         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3968             self._setitem_array(key, value)
#    3969         elif isinstance(value, DataFrame):
#    3970             self._set_item_frame_value(key, value)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    4008
#    4009             if isinstance(value, DataFrame):
# -> 4010                 check_key_length(self.columns, key, value)
# ...

# %%
    # Lista adresów sklepów Żabka...


df = pd.DataFrame({'Address': zabki})
df_zabki_wspolrzedne =
# Out:
#                                  Address
# 0        ul. 10 Lutego 32 lok. 4, Gdynia
# 1                    10 Lutego 9, Gdynia
# 2                      3 Maja 20, Gdynia
# 3    al. Piłsudskiego 32A lok.U1, Gdynia
# 4              Arenda Dickmana 4, Gdynia
# ..                                   ...
# 126          WŁADYSŁAWA IV 46/U4, Gdynia
# 127           Wójta Radtkego 47A, Gdynia
# 128             Zaruskiego 10/U1, Gdynia
# 129                   Zielona 23, Gdynia
# 130        Zwycięstwa 239 lok. 2, Gdynia
#
# [131 rows x 1 columns]

# %%
dobre_zaby = [('54.51929695', '18.54021235132901'),
('54.5207646', '18.5353122'),
('54.52380805', '18.50973143795128'),
('54.5487545', '18.521534'),
('54.5542732', '18.5246895'),
('54.5519029', '18.5009695'),
('54.549623', '18.5362604'),
('54.4721341', '18.5034613'),
('54.5509079', '18.5143232'),
('54.54792205', '18.442589956200575'),
('54.5387507', '18.478844'),
('54.54257115', '18.469531614749762'),
('54.4778025', '18.503525'),
('54.521800850000005', '18.545247718797885'),
('54.562494400000006', '18.48262659914449'),
('54.5396227', '18.4596092'),
('54.5441152', '18.4619611'),
('54.4923669', '18.5422006'),
('54.5291185', '18.5028536'),
('54.5354355', '18.4793177'),
('54.5196977', '18.5374641'),
('54.5431956', '18.4532475'),
('54.4687603', '18.5064625'),
('54.468460449999995', '18.464148835342442'),
('54.5233736', '18.5433361'),
('54.483444750000004', '18.53781780528743'),
('54.4627455', '18.4548945'),
('54.5195001', '18.5462707'),
('54.4978684', '18.5055284'),
('54.53637775', '18.44809827164819'),
('54.5086508', '18.5379129'),
('54.5195018', '18.5426081'),
('54.498129950000006', '18.512236294556672'),
('54.5105785', '18.5429911'),
('54.5081877', '18.5488728'),
('54.5601271', '18.5072807'),
('54.4989996', '18.5417644'),
('54.5495901', '18.5262032'),
('54.531687149999996', '18.492602227929233'),
('54.5385746', '18.4705799'),
('54.5211365', '18.5271412'),
('54.5211365', '18.5271412'),
('54.4995487', '18.5154256'),
('54.5001489', '18.5058934'),
('54.4773559', '18.520156163763787'),
('54.5339463', '18.4936566'),
('54.4695479', '18.5175215'),
('54.539772', '18.4648188'),
('54.5620784', '18.4924377'),
('54.5156997', '18.5325709'),
('54.5363373', '18.450112520855615'),
('54.5211046', '18.54047823568979'),
('54.5378097', '18.4628863'),
('54.509927', '18.538211'),
('54.5208931', '18.5428884'),
('54.5180898', '18.5215508'),
('54.4711384', '18.4536662'),
('54.5134354', '18.5316469'),
('54.4997155', '18.50859'),
('54.5062486', '18.5508531'),
('54.5207155', '18.5391494'),
('54.5174318', '18.5386218'),
('54.5585107', '18.4839441'),
('54.4699804', '18.4961491'),
('54.5404526', '18.4773458'),
('54.49576005', '18.50881751907168'),
('54.5174318', '18.5386218'),
('54.5219313', '18.5326633'),
('54.4939336', '18.4306437'),
('54.5528054', '18.5295732')]

# %%
niezle_zaby = pd.DataFrame(dobre_zaby, columns=['geometry'])


# Convert the DataFrame to a GeoDataFrame
niezle_zaby = gpd.GeoDataFrame(dobre_zaby, crs='EPSG:4326')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-2871f7f335e9> in <cell line: 5>()
#       3
#       4 # Convert the DataFrame to a GeoDataFrame
# ----> 5 niezle_zaby = gpd.GeoDataFrame(dobre_zaby, crs='EPSG:4326')
#
# /usr/local/lib/python3.10/dist-packages/geopandas/geodataframe.py in __init__(self, data, geometry, crs, *args, **kwargs)
#     192
#     193         if geometry is None and crs:
# --> 194             raise ValueError(
#     195                 "Assigning CRS to a GeoDataFrame without a geometry column is not "
#     196                 "supported. Supply geometry using the 'geometry=' keyword argument, "
#
# ValueError: Assigning CRS to a GeoDataFrame without a geometry column is not supported. Supply geometry using the 'geometry=' keyword argument, or by providing a DataFrame with column name 'geometry'

# %%
niezle_zaby.rename(columns={'0':'geometry'}, inplace=True)
# Out:
# None

# %%
niezle_zaby
# Out:
#                                 0
# 0   54.51929695 18.54021235132901
# 1           54.5207646 18.5353122
# 2   54.52380805 18.50973143795128
# 3            54.5487545 18.521534
# 4           54.5542732 18.5246895
# ..                            ...
# 65  54.49576005 18.50881751907168
# 66          54.5174318 18.5386218
# 67          54.5219313 18.5326633
# 68          54.4939336 18.4306437
# 69          54.5528054 18.5295732
#
# [70 rows x 1 columns]

# %%
address_coordinates_dict

# %%
df_coordinates
# Out:
#      Latitude  Longitude                  Dzielnice
# 0   54.581090  18.539655                 Babie Doly
# 1   54.502146  18.466309          Chwarzno-Wiczlino
# 2   54.544120  18.469076                   Chylonia
# 3   54.549197  18.444791                     Cisowa
# 4   54.514737  18.532677              Dzialki Lesne
# 5   54.471925  18.462430                    Dabrowa
# 6   54.526834  18.511630                   Grabowek
# 7   54.511642  18.546799              Kamienna Gora
# 8   54.473447  18.490217                    Karwiny
# 9   54.533020  18.488830                 Leszczynki
# 10  54.477864  18.522656                  Maly Kack
# 11  54.552381  18.515204                     Obluze
# 12  54.549540  18.539610                    Oksywie
# 13  54.479333  18.552430                     Orlowo
# 14  54.558545  18.475330                    Pogorze
# 15  54.533642  18.452914  Pustki Cisowskie-Demptowo
# 16  54.492582  18.546783                    Redlowo
# ...

# %%
geometry = [Point(lon, lat) for lon, lat in zip(df_coordinates['Longitude'], df_coordinates['Latitude'])]
gdf = gpd.GeoDataFrame(df_coordinates, crs='EPSG:4326', geometry=geometry)

# %%
gdf
# Out:
#      Latitude  Longitude                  Dzielnice                   geometry
# 0   54.581090  18.539655                 Babie Doly  POINT (18.53965 54.58109)
# 1   54.502146  18.466309          Chwarzno-Wiczlino  POINT (18.46631 54.50215)
# 2   54.544120  18.469076                   Chylonia  POINT (18.46908 54.54412)
# 3   54.549197  18.444791                     Cisowa  POINT (18.44479 54.54920)
# 4   54.514737  18.532677              Dzialki Lesne  POINT (18.53268 54.51474)
# 5   54.471925  18.462430                    Dabrowa  POINT (18.46243 54.47192)
# 6   54.526834  18.511630                   Grabowek  POINT (18.51163 54.52683)
# 7   54.511642  18.546799              Kamienna Gora  POINT (18.54680 54.51164)
# 8   54.473447  18.490217                    Karwiny  POINT (18.49022 54.47345)
# 9   54.533020  18.488830                 Leszczynki  POINT (18.48883 54.53302)
# 10  54.477864  18.522656                  Maly Kack  POINT (18.52266 54.47786)
# ...

# %%
zabka_list
# Out:
# [{'adres_zabki': '10 Lutego 9, Gdynia', 'geometry': <POINT (18.54 54.519)>},
#  {'adres_zabki': '3 Maja 20, Gdynia', 'geometry': <POINT (18.535 54.521)>},
#  {'adres_zabki': 'Beniowskiego 29, Gdynia',
#   'geometry': <POINT (18.51 54.524)>},
#  {'adres_zabki': 'Benisławskiego 1, Gdynia',
#   'geometry': <POINT (18.522 54.549)>},
#  {'adres_zabki': 'Benisławskiego 48, Gdynia',
#   'geometry': <POINT (18.525 54.554)>},
#  {'adres_zabki': 'Boisko 11, Gdynia', 'geometry': <POINT (18.501 54.552)>},
#  {'adres_zabki': 'Bosmańska 38, Gdynia', 'geometry': <POINT (18.536 54.55)>},
#  {'adres_zabki': 'Buraczana 25, Gdynia', 'geometry': <POINT (18.507 54.473)>},
#  {'adres_zabki': 'Cechowa 8, Gdynia', 'geometry': <POINT (18.514 54.551)>},
#  {'adres_zabki': 'Chylońska 251B, Gdynia',
#   'geometry': <POINT (18.443 54.548)>},
#  {'adres_zabki': 'Chylońska 26, Gdynia', 'geometry': <POINT (18.479 54.539)>},
#  {'adres_zabki': 'Chylońska 91A, Gdynia', 'geometry': <POINT (18.47 54.543)>},
# ...

# %%
df_dobre_zaby = pd.DataFrame(dobre_zaby)
df_dobre_zaby
# Out:
#                                 0
# 0   54.51929695 18.54021235132901
# 1           54.5207646 18.5353122
# 2   54.52380805 18.50973143795128
# 3            54.5487545 18.521534
# 4           54.5542732 18.5246895
# ..                            ...
# 65  54.49576005 18.50881751907168
# 66          54.5174318 18.5386218
# 67          54.5219313 18.5326633
# 68          54.4939336 18.4306437
# 69          54.5528054 18.5295732
#
# [70 rows x 1 columns]

# %%
map_gdynia
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
dobre_zaby
# Out:
# [('54.51929695', '18.54021235132901'),
#  ('54.5207646', '18.5353122'),
#  ('54.52380805', '18.50973143795128'),
#  ('54.5487545', '18.521534'),
#  ('54.5542732', '18.5246895'),
#  ('54.5519029', '18.5009695'),
#  ('54.549623', '18.5362604'),
#  ('54.4721341', '18.5034613'),
#  ('54.5509079', '18.5143232'),
#  ('54.54792205', '18.442589956200575'),
#  ('54.5387507', '18.478844'),
#  ('54.54257115', '18.469531614749762'),
#  ('54.4778025', '18.503525'),
#  ('54.521800850000005', '18.545247718797885'),
#  ('54.562494400000006', '18.48262659914449'),
#  ('54.5396227', '18.4596092'),
#  ('54.5441152', '18.4619611'),
#  ('54.4923669', '18.5422006'),
#  ('54.5291185', '18.5028536'),
#  ('54.5354355', '18.4793177'),
#  ('54.5196977', '18.5374641'),
#  ('54.5431956', '18.4532475'),
#  ('54.4687603', '18.5064625'),
#  (',54.468460449999995', '18.464148835342442'),
#  ('54.5233736', '18.5433361'),
#  ('54.483444750000004', '18.53781780528743'),
#  ('54.4627455', '18.4548945'),
# ...

# %%
df_dobre_zaby = pd.DataFrame(dobre_zaby, columns=["Latitude", "Longitude"])

# %%
df_dobre_zaby
# Out:
#        Latitude          Longitude
# 0   54.51929695  18.54021235132901
# 1    54.5207646         18.5353122
# 2   54.52380805  18.50973143795128
# 3    54.5487545          18.521534
# 4    54.5542732         18.5246895
# ..          ...                ...
# 65  54.49576005  18.50881751907168
# 66   54.5174318         18.5386218
# 67   54.5219313         18.5326633
# 68   54.4939336         18.4306437
# 69   54.5528054         18.5295732
#
# [70 rows x 2 columns]

# %%
map_gdynia = folium.Map(location=[latitude, longitude], zoom_start=11)


for lat, lng, label in zip(df_coordinates['Latitude'], df_coordinates['Longitude'], df_coordinates["Dzielnice"]):
    label = folium.Popup(remove_accents(label), parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_gdynia)

map_gdynia

# %%
for lat, lon in zip(df_dobre_zaby['Latitude'], df_dobre_zaby['Longitude']):

  folium.CircleMarker(
      [lat, lon],
      radius=1,
      popup='Żabka',
      color='green',
      fill=True,
      fill_color= '#59cc20',
      fill_opacity = 0.5,
      ).add_to(map_gdynia)

map_gdynia
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# Nazwa dzielnicy  Gęstość zaludnienia[osób/km²]                Liczba Żabek
# 8              Kamienna Góra                         5958.0   4
# 3                   Chylonia                         5395.0   10
# 15                   Pogórze                         5183.0   3
# 21  Wzgórze św. Maksymiliana                         5164.0   1
# 12                    Obłuże                         4808.0   8
# 5              Działki Leśne                         3786.0   3
# 13                   Oksywie                         3286.0   1
# 9                    Karwiny                         2871.0   3
# 17                   Redłowo                         2698.0   1
# 10                Leszczynki                         2592.0   2

# %%
 df_gdynia

# %%
#Dzielnice z najwyższą gęstością zaludnienia
top_dzielnice = df_gdynia[1:].nlargest(10, 'Gęstość zaludnienia[osób/km²]')

print(top_dzielnice[['Nazwa dzielnicy', 'Gęstość zaludnienia[osób/km²]']])
# Out:
#              Nazwa dzielnicy  Gęstość zaludnienia[osób/km²]
# 8              Kamienna Góra                         5958.0
# 3                   Chylonia                         5395.0
# 15                   Pogórze                         5183.0
# 21  Wzgórze św. Maksymiliana                         5164.0
# 12                    Obłuże                         4808.0
# 5              Działki Leśne                         3786.0
# 13                   Oksywie                         3286.0
# 9                    Karwiny                         2871.0
# 17                   Redłowo                         2698.0
# 10                Leszczynki                         2592.0

# %%
 a = top_dzielnice['Gęstość zaludnienia[osób/km²]']
 b =
# Out:
# [5958.0,
#  5395.0,
#  5183.0,
#  5164.0,
#  4808.0,
#  3786.0,
#  3286.0,
#  2871.0,
#  2698.0,
#  2592.0]

# %%
Nazwa dzielnicy  Gęstość zaludnienia[osób/km²]                Liczba Żabek
8              Kamienna Góra                         5958.0   4
3                   Chylonia                         5395.0   10
15                   Pogórze                         5183.0   3
21  Wzgórze św. Maksymiliana                         5164.0   0
12                    Obłuże                         4808.0   8
5              Działki Leśne                         3786.0   3
13                   Oksywie                         3286.0   1
9                    Karwiny                         2871.0   3
17                   Redłowo                         2698.0   1
10                Leszczynki                         2592.0   2
